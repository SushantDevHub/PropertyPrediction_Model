# %%
import pandas as pd
df = pd.read_csv('HOMEPRICE.CSV')
df
# Out:
#    AREA    PRICE
# 0  2600  5500000
# 1  3000  5650000
# 2  3200  6100000
# 3  3600  6800000
# 4  4000  7250000

# %%
import matplotlib.pyplot as plt
plt.plot(df.AREA,df.PRICE)
plt.xlabel('AREA')
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %%
import matplotlib.pyplot as plt

plt.scatter(df.AREA,df.PRICE,color='red',marker='*')
plt.xlabel('AREA')
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %%
new_df = df.drop('PRICE',axis='columns')
new_df
# Out:
#    AREA
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
PRICE = df.PRICE
PRICE
# Out:
# 0    5500000
# 1    5650000
# 2    6100000
# 3    6800000
# 4    7250000
# Name: PRICE, dtype: int64

# %%
from sklearn import linear_model
REG = linear_model.LinearRegression()
REG.fit(new_df,PRICE)
# Out:
# LinearRegression()

# %%
REG.predict([[3400]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6422945.20547945])

# %%
REG.predict([[4200]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7509246.57534247])

# %%
REG.coef_
# Out:
# array([1357.87671233])

# %%
REG.intercept_
# Out:
# np.float64(1806164.3835616438)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
df = pd.read_csv('HOUSE.CSV')
df
# Out:
#    area  bedrooms    age    price
# 0  2600          3    20  5500000
# 1  3000          4    15  5650000
# 2  3200               18   610000
# 3  3600          3    30  5950000
# 4  4000          5     8  7600000
# 5  4100          6     8  8100000

# %%
df[:]
# Out:
#    area  bedrooms    age    price
# 0  2600          3    20  5500000
# 1  3000          4    15  5650000
# 2  3200               18   610000
# 3  3600          3    30  5950000
# 4  4000          5     8  7600000
# 5  4100          6     8  8100000

# %%
print(df.columns)
# Out:
# Index(['area', ' bedrooms ', ' age', ' price'], dtype='object')

# %%
df['bedrooms'] = pd.to_numeric(df['bedrooms'], errors ='coerce')
df['bedrooms'].median()
# Out:
# 4.0

# %%
df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())
df
# Out:
#    area  bedrooms  age    price
# 0  2600       3.0   20  5500000
# 1  3000       4.0   15  5650000
# 2  3200       4.0   18   610000
# 3  3600       3.0   30  5950000
# 4  4000       5.0    8  7600000
# 5  4100       6.0    8  8100000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3000,3,40]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([797766.27319482])

# %%
reg.coef_
# Out:
# array([    3599.62616399, -1785259.98595283,  -227809.62306757])

# %%
reg.intercept_
# Out:
# np.float64(4467052.66178792)
